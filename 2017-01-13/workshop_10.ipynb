# %% [markdown]
# <h1>Workshop n°10 di GGPL di Emanuele Chiossi, mat. 439468</h1>
# <h3>Housing: coherent assembly of plugins</h3>

# %% [markdown]
# <h2>Descrizione</h2>

# %% [markdown]
# L'obiettivo dell'homework numero 10 è quello di realizzare una casa, completa di mura perimetrali, muri esterni, porte, finestre, una scala in caso di necessità ed il tetto.
#
# Lo scopo è quello di utilizzare le funzioni sviluppate negli homework svolti in precedenza, per cui sono stati prodotti dei file .py che li contengono:
# <ul>
# <li>door.py: contiene le funzioni necessarie per la realizzazione di una porta (homework_07)</li>
# <li>window.py: contiene le funzioni necessarie per la realizzazione di una finestra (homework_07)</li>
# <li>stairs.py: contiene le funzioni necessarie per la realizzazione di una scala (homework_03)</li>
# <li>roof.py: contiene le funzioni necessarie per la realizzazione di un tetto(homework_09)</li>
# <li>support.py: contiene alcune funzioni di supporto necessarie allo sviluppo degli altri homework</li>
# </ul>
#
# Come ispirazione per la struttura della casa, è stata presa la seguente immagine dal web:
# ![text alt](screen/progetto.png)<br>
# Il primo step in questo homework consiste nel creare i file .lines necessari alla costruzione della casa.
# Per farlo sono stati dati in pasto a http://cvdlab.github.io/svg2lines/ i file .svg prodotti utilizzando l'editor Inkscape (per "ricalcare" la struttura di riferimento e realizzare il modello).
#
# Si è scelto di realizzare il disegno su più livelli (layer):
# <ul>
# <li>il primo layer rappresenta i muri portanti della casa, ovvero i muri di cemento armato che sorreggono la struttura</li>
# <li>il secondo layer rappresenta i muri interni della casa, ovvero i muri che separano le varie stanze l'una dall'altra</li>
# <li>il terzo layer rappresenta le aree da dover lasciar libere nella struttura per poter inserire le porte</li>
# <li>il quarto layer rappresenta le aree da lasciar libere nella struttura per poter inserire le finestre</li>
# <li>il quinto layer rappresenta le aree da lasciar libere nella struttura per poter inserire le scale</li>
# <li>il sesto layer rappresenta le aree da lasciar libere nella struttura per poter inserire le serrande</li>
# <li>il settimo layer rappresenta il pavimento della casa</li>
# <li>il ottavo layer rappresenta il pavimento del bagno della casa</li>
# <li>il nono layer rappresenta il pavimento del garage della casa</li>
# </ul>
#
# Di seguito le immagini che illustrano i layer realizzati per creare il piano terra della casa:
# <br>perimetro:
# ![text alt](screen/piano terra/perimetro.jpg)<br>interni:
# ![text alt](screen/piano terra/interni.jpg)<br>porte:
# ![text alt](screen/piano terra/porta.jpg)<br>finestre:
# ![text alt](screen/piano terra/finestra.jpg)<br>scale:
# ![text alt](screen/piano terra/scale.jpg)<br>serranda:
# ![text alt](screen/piano terra/serranda.jpg)<br>pavimento:
# ![text alt](screen/piano terra/pavimentoP.jpg)<br>pavimento del bagno:
# ![text alt](screen/piano terra/pavimentoB.jpg)<br>pavimento del garage:
# ![text alt](screen/piano terra/pavimentoG.jpg)<br>
#
# Per quanto riguarda il codice, le funzioni principali su cui l'homework si basa sono le seguenti:
# <ul>
# <li>la funzione buildingElement, dati in input un file .lines ed una stringa che specifica il tipo dell'elemento che si andrà a costruire, restituisce una lista di elementi con dimensione e posizione stabiliti in base ai parametri presenti nel file .lines. Nello specifico, a seconda del tipo di elemento, si andranno a costruire parallelepipedi nella posizione definita dai file. <br>
# Le variabili principali utilizzate in questa funzione sono:
# <ul>
# <li>elementsList: lista degli elementi costruiti, restituita in output</li>
# <li>acc: contatore per memorizzare le coppie due a due</li>
# <li>cuboid: lista che contiene i punti da passare poi all'MKPOL</li>
# <li>elements: struct degli elementi in elementsList</li>
# </ul>
# </li><br>
# <li>la funzione drawPlans, dati in input tutti i parametri necessari alla creazione del piano di una casa, lo costruisce e lo restituisce. <br>
# Le variabili principali utilizzate in questa funzione sono:
# <ul>
# <li>perimetro: file necessario alla costruzione del perimetro</li>
# <li>interni: file necessario alla costruzione dei muri interni</li>
# <li>porte: file necessario alla costruzione delle porte</li>
# <li>serrande: file necessario alla costruzione delle serrande</li>
# <li>finestre: file necessario alla costruzione delle finestre</li>
# <li>pavimentoX: file necessario alla costruzione del pavimento dell'ambiente X</li>
# <li>externalWall: muro esterno della casa</li>
# <li>internalWall: muro interno della casa</li>
# <li>doorBox: box nel quale verranno alloggiate le porte</li>
# <li>garageBox: box nel quale verrà alloggiata la serranda</li>
# <li>windowsBox: box nel quale verranno alloggiate le finestre</li>
# <li>wallsENoDoorEWindow: muro esterno con i buchi per le porte e le finestre (eventualmente anche serrande)</li>
# <li>wallsINoDoor: muro interno con i buchi per le porte</li>
# <li>walls: muri della casa</li>
# <li>floorX: pavimento X della casa</li>
# <li>floor: pavimento completo della casa</li>
# <li>stairs: scale della casa</li>
# <li>principDoor: porta di ingresso della casa</li>
# <li>doors: porte situate all'interno della casa</li>
# <li>windows: finestre della casa</li>
# <li>garageDoor: serranda del garage della casa</li>
# <li>plan: piano della casa</li>
# </ul>
# </li><br>
# <li>la funzione insertElement, dato in input un file .lines, il tipo dell'elemento e il muro di interesse, crea gli elementi e li posiziona al giusto posto, sfruttando la funzione di appoggio positionElement.<br>
# Le variabili principali utilizzate nella funzione sono le seguenti:
# <ul>
# <li>dimAndPosElements: lista che contiene la posizione e la dimensione dei box in cui dovranno poi essere inseriti gli elementi (porte, finestre, ecc..)</li>
# <li>wall2: spazio che rappresenta il box disegnato con inkscape per l'elemento</li>
# <li>element: spazio che rappresenta il box in cui alloggiare l'elemento</li>
# <li>sizeElement: dimensioni del box in cui si alloggia l'elemento</li>
# <li>elements: lista degli elementi veri e propri</li>
# <li>element in for: elemento creato</li>
# </ul>
# </li><br>
# <li>la funzione multistoreyHouse ha il compito di realizzare la casa ed il relativo tetto dati come parametro gli elementi di costruzione.<br>
# Le variabili principali utilizzate in questa funzione sono:
# <ul>
# <li>elementOfPlanT: elementi di costruzione del piano terra della casa</li>
# <li>elementOfPlanP: elementi di costruzione del primo piano della casa</li>
# <li>entriesT: porte, finestre e serranda del piano terra</li>
# <li>floorsT: pavimenti del piano terra</li>
# <li>wallsT: muri del piano terra</li>
# <li>entriesP: porte, finestre e serranda del primo piano</li>
# <li>floorsP: pavimenti del primo piano</li>
# <li>wallsP: muri del primo piano</li>
# <li>plan1: piano terra della casa</li>
# <li>plan2: primo piano della casa</li>
# <li>house: casa, l'obiettivo dell'homework</li>
# <li>roofMeasure: calcolo delle misure e della posizione del tetto</li>
# <li>roof: tetto della casa</li>
# </ul><br>
# </li>
# </ul>
# <br>
# Si è cercato il più possibile di realizzare un progetto in grado di disegnare una casa qualsiasi siano le forme dei suoi input, dal numero dei piani alla distribuzione interna delle pareti, dalla forma del tetto alla geometria del perimetro.
# <br><br>
# Ulteriori specifiche relative alle strategie implementative e al modus operandi sono espresse nel codice sotto forma di commento.
# <br><br>
# Per abbellire la struttura, sono state utilizzate le seguenti texture:
#
# muri perimetrali:![text alt](texture/muri.jpg)
# muri interni:![text alt](texture/interni.jpg)
# parquet della casa:![text alt](texture/parquet.jpg)
# scale:![text alt](texture/scale.jpg)
# serranda:![text alt](texture/serranda.jpg)
# tegole:![text alt](texture/tegole.jpg)
# pavimento del bagno:![text alt](texture/pavimentoBagno.jpg)
# pavimento del garage:![text alt](texture/pavimentoGarage.jpg)
# <br>
# Il codice prodotto per questo homework è il seguente:

# %%
#import della libreria che si occupa della realizzazione della porta
from door import *
#import della libreria che si occupa della realizzazione della finestra
from window import *
#import della libreria che si occupa della realizzazione delle scale
from stairs import *
#import della libreria che si occupa della realizzazione del tetto
from roof import *
#import della libreria che fornisce funzioni di supporto per la realizzazione del tetto e della casa
from support import *
# Out:
# Evaluating fenvs.py..
# ...fenvs.py imported in 0.00587 seconds

# %%
#dati in input un file .lines ed una stringa che specifica il tipo dell'elemento che si andrà a costruire, il metodo 
#restituisce una lista di elementi con dimensione e posizione stabiliti in base ai parametri presenti nel file .lines  
def building_element(filename, elementType):
    #creazione dell'elemento
    with open(filename, "rb") as file:#lettura del file
        reader = csv.reader(file, delimiter=",")
        elementsList = []
        #nel caso di porte, finestre, pavimento, scala o serrande
        if elementType=="porte" or elementType=="finestre" or elementType=="pavimento" or elementType=="scale" or elementType=="serrande":
            cuboid = []
            acc = 0
            for row in reader:#leggo ogni riga
                acc = acc + 1
                cuboid.append([float(row[1]),float(row[0])])#memorizzo le coppie di punti due a due
                if(acc == 4):
                    elementsList.append(MKPOL([cuboid,[[1,2,3,4]],None]))#creo una faccia che riempie lo spazio stabilito
                    cuboid = []
                    acc = 0
        #nel caso di perimetro e interni è sufficiente una riga            
        if elementType=="perimetro" or elementType=="interni":
            for row in reader:
                elementsList.append(POLYLINE([[float(row[1]), float(row[0])],[float(row[3]), float(row[2])]]))
    elements = STRUCT(elementsList)#creo uno struct degli elementi sopra ricavati
    #tramite PROD produco un elemento tridimensionale
    #le altezze sono proporzionate alla dimensione della casa prima del resize
    if elementType=="perimetro": 
        elements = OFFSET([6,6])(elements)
        elements = PROD([elements, Q(100)])
    elif elementType=="interni":
        elements = OFFSET([3,3])(elements)        
        elements = PROD([elements, Q(99.9)])
    #per porte, finestre e serrande si restituiscono solo i box in cui saranno alloggiate, sarà
    #compito di un altro metodo creare l'elemento nello specifico e posizionarlo dove si trova il box
    elif elementType=="porte":
        elements = PROD([elements, Q(70)])        
    elif elementType=="serrande":
        elements = PROD([elements, Q(70)])
        dimAndPos = getDimensionAndPosition(elements)
        elements = T([1,2,3])([dimAndPos[1][0]*.03*2,dimAndPos[1][1]*.03*2,dimAndPos[1][2]*.03*2])(elements)
    elif elementType=="finestre":
        elements = OFFSET([3,3])(elements)        
        elements = PROD([elements, Q(50)])
        elements = T(3)(25)(elements)
    elif elementType=="scale":
        elements = PROD([elements, Q(100)])
        dimAndPos = getDimensionAndPosition(elements)
        #nel caso della scala, dato che è unica, la si costruisce direttamente qui richiamando la funzione
        #generata nell'homework_03 e presente nella libreria stairs.py
        app = ggpl_building_stairs(6,3,6)
        #si adatta la scala alle dimensioni dello spazio disposibile e la si posiziona li
        app = resizeDim(app,dimAndPos[0][0],dimAndPos[0][1],dimAndPos[0][2])
        app = T([1,2,3])([dimAndPos[1][0]*(1/.03),dimAndPos[1][1]*(1/.03),dimAndPos[1][2]*(1/.03)])(app)
        elements = app        
    return elements


#funzione che disegna un piano di una casa dati in input tutto il necessario alla sua creazione
def drawPlans(npiano, walls, entries, floors, scale): 
    #mi prendo i singoli elementi per mantenere il codice più chiaro possibile
    perimetro = walls[0]
    interni = walls[1]
    porte = entries[0]
    serrande = entries[1]
    finestre = entries[2]
    pavimentoP = floors[0]#pavimento generale
    pavimentoB = floors[1]#pavimento del bagno
    pavimentoG = floors[2]#pavimento del garage
    externalWall = building_element(perimetro, "perimetro")#costruisco il muro esterno
    internalWall = building_element(interni, "interni")#costruisco il muro interno
    doorBox = building_element(porte, "porte")#costruisco i box in cui dovranno essere alloggiate le porte
    if serrande!=None:
        garageBox = building_element(serrande, "porte")#costruisco i box in cui dovranno essere alloggiate le serrande
    windowsBox = building_element(finestre, "finestre")#costruisco i box in cui dovranno essere alloggiate le finestre
    #costruisco il muro esterno con i buchi per le porte e le finestre
    wallsENoDoorEWindow=DIFFERENCE([externalWall,STRUCT([doorBox,windowsBox])])
    if serrande!=None:
        #costruisco il muro esterno con i buchi per le serrande
        wallsENoDoorEWindow=DIFFERENCE([wallsENoDoorEWindow, garageBox])
    wallsENoDoorEWindow = TEXTURE(['texture/muri.jpg',TRUE,FALSE,1,1,0,150,150])(wallsENoDoorEWindow)
    wallsINoDoor=DIFFERENCE([internalWall,doorBox])#costruisco il muro interno con i buchi per le porte
    wallsINoDoor = TEXTURE(['texture/interni.jpg',TRUE,FALSE,1,1,0,15,20])(wallsINoDoor)
    walls = STRUCT([wallsENoDoorEWindow,wallsINoDoor])#accorpo in un unica variabile i muri della casa
    floorP = building_element(pavimentoP,"pavimento")#costruisco il pavimento generale
    floorP = TEXTURE(['texture/parquet.jpg',TRUE,FALSE,1,1,0,15,20])(floorP)
    floorB = building_element(pavimentoB,"pavimento")#costruisco il pavimento del bagno
    floorB = TEXTURE(['texture/pavimentoBagno.jpg',TRUE,FALSE,1,1,0,15,20])(floorB)    
    if pavimentoG!=None:
        floorG = building_element(pavimentoG,"pavimento")#costruisco il pavimento del garage
        floorG = TEXTURE(['texture/pavimentoGarage.jpg',TRUE,FALSE,1,1,0,15,20])(floorG)
        floor = STRUCT([floorP, floorG, floorB])#accorpo in un unica variabile i pavimenti
    else:
        floor = STRUCT([floorP, floorB])        
    if scale != None:
        stairs = building_element(scale,"scale")#costruisco le scale
        stairs = TEXTURE(['texture/scale.jpg',TRUE,FALSE,1,1,0,1,1])(stairs)
    if npiano=="terra":
        #inserisco nel box opportuno la porta di ingresso
        principDoor = insertElement(porte,"porte",externalWall) 
    #inserisco nei box opportuni le altre porte     
    doors = insertElement(porte,"porte",internalWall) 
    #inserisco nei box opportuni le finestre
    windows = insertElement(finestre,"finestre",externalWall)
    if serrande!=None:
        garageDoor = building_element(serrande, "serrande")#costruisco la serranda
        garageDoor = TEXTURE(['texture/serranda.jpg',TRUE,FALSE,1,1,0,1,1])(garageDoor)
    #accorpo tutti gli elementi di un piano della casa in una unica variabile: plan
    if scale != None and serrande!=None: 
        plan = STRUCT([walls, floor, stairs, garageDoor])
    elif serrande!=None: 
        plan = STRUCT([walls, floor, garageDoor])
    else: 
        plan = STRUCT([walls, floor])        
    plan = S([1,2,3])([.03,.03,.03])(plan)
    if npiano=="terra":
        plan = STRUCT([plan,doors,principDoor,windows])
    else:
        plan = STRUCT([plan,doors,windows])
    return plan

#funzione di appoggio che dato in input un file .lines, il tipo dell'elemento e il muro di interesse
#costruisce e restituisce una lista dei box in cui devono essere allocati gli elementi
def positionElement(filename, elementType, wall):
    with open(filename, "rb") as file:
        reader = csv.reader(file, delimiter=",")
        elementsList = []
        if elementType=="porte" or elementType=="finestre":
            cuboid = []
            acc = 0
            for row in reader:
                acc = acc + 1
                cuboid.append([float(row[1]),float(row[0])])
                if(acc == 4):
                    cub = STRUCT([MKPOL([cuboid,[[1,2,3,4]],None])])
                    if elementType=="porte":
                        cub = PROD([cub,Q(70)])
                    elif elementType=="finestre":
                        cub = PROD([cub, Q(SIZE([3])(wall)[0]/2.)])
                        cub = T(3)(SIZE([3])(wall)[0]/4.)(cub)
                    elementsList.append(cub)
                    cuboid = []
                    acc = 0
    return elementsList

#dato in input un file .lines, il tipo dell'elemento e il muro di interesse, la funzione crea gli elementi veri
#e propri e li inserisce negli spazi a loro destinati, sfruttando la funzione di appoggio positionElement
def insertElement(fileName, elementType, wall):#fileName, elementType, wall    
    dimAndPosElements = []
    if elementType=="porte" or elementType=="finestre":
        for elem in positionElement(fileName,elementType, wall):
            wall2 = DIFFERENCE([wall, elem])#spazio che rappresenta il box disegnato con inkscape per l'elemento
            element = DIFFERENCE([wall, wall2])#spazio che rappresenta il box in cui alloggiare l'elemento
            sizeElement = SIZE([1,2])(element)
            if sizeElement[0]!=0.0 and sizeElement[1]!=0.0:#controllo di integrità
                dimAndPosElements.append(getDimensionAndPosition(element))
        elements =[]
        for d in dimAndPosElements:#per ogni box da riempire
            if d[0][0]>d[0][1]:#se l'oggetto si sviluppa sull'asse x
                if elementType=="porte":
                    #creo la porta richiamando la funzione generata nell'homework_07 e presente nella libreria door.py
                    element = createDoor([XD,YD,ZD],occupancyD)(1.2,.05,2.1)
                    #oriento l'elemento sull'asse x
                    element = rotation(element,2)
                    #ridimensiono l'elemento in base alle dimensioni del box opportunamente scalate
                    element = resizeDim(element,d[0][0]*.03,d[0][1]*.03,d[0][2]*.03)
                elif elementType=="finestre":
                    #creo la finestra richiamando la funzione generata nell'homework_07 e presente
                    #nella libreria window.py
                    element = createWindow([XW,YW,ZW],occupancyW)(3.6,.05,2.29)
                    #oriento l'elemento sull'asse x                    
                    element = rotation(element,2)
                    #ridimensiono l'elemento in base alle dimensioni del box opportunamente scalate
                    element = resizeDim(element,d[0][0]*.0315,d[0][1]*.03,d[0][2]*.03)
            else:#se l'oggetto si sviluppa sull'asse y, come sopra ma orientato sull'asse y
                if elementType=="porte":                                
                    element = createDoor([XD,YD,ZD],occupancyD)(1.2,.05,2.1)
                    element = rotation(element,1)
                    element = resizeDim(element,d[0][0]*.03,d[0][1]*.03,d[0][2]*.03)
                elif elementType=="finestre":
                    element = createWindow([XW,YW,ZW],occupancyW)(3.6,.05,2.29)
                    element = rotation(element,1)
                    element = resizeDim(element,d[0][0]*.03,d[0][1]*.031,d[0][2]*.03)
            element = STRUCT([T([1,2,3])(d[1]),element])
            #aggiusto la posizione delle porte e delle finestre se occorre, alcuni elementi potrebbero essere
            #posizionati troppo all'interno o all'esterno della casa e non con precisione a filo del muro a causa
            #di errori da parte dell'utilizzatore di inkscape
            if elementType=="porte":
                if d[0][0]>d[0][1]:
                    element = STRUCT([T(2)(-YD[0]),element])
                else:
                    element = STRUCT([T(1)(-YD[0]),element])
            elif elementType=="finestre":
                if d[0][0]>d[0][1]:
                    element = STRUCT([T(2)(-6*YW[0]),element])
                else:
                    element = STRUCT([T(1)(-4*YW[0]),element])
            elements.append(element)
        return STRUCT(elements)

#dati gli elementi di ogni piano in un array, la funzione costruisce la casa ed il relativo tetto
def multistoreyHouse(elementsOfHouse):
    elementOfPlanT = elementsOfHouse[0]#elementi del piano terra
    elementOfPlanP = elementsOfHouse[1]#elementi del primo piano
    entriesT = elementsOfPlanT[0]#porte, finestre e serranda del piano terra
    floorsT = elementsOfPlanT[1]#pavimenti del piano terra
    wallsT = elementsOfPlanT[2]#muri del piano terra
    entriesP = elementsOfPlanP[0]#porte, finestre e serranda del primo piano
    floorsP = elementsOfPlanP[1]#pavimenti del primo piano
    wallsP = elementsOfPlanP[2]#muri del primo piano
    plan1 = drawPlans("terra",wallsT,entriesT,floorsT,"piano terra/scale.lines")#costruzione del piano terra 
    plan2 = T(3)(3)(drawPlans("primo",wallsP,entriesP,floorsP, None))#costruzione del primo piano
    house = STRUCT([plan1,plan2])#costruzione della casa
    roofMeasure = getDimensionAndPosition(house)#calcolo delle misure e della posizione del tetto
    #creo il tetto richiamando la funzione generata nell'homework_09 e presente nel package roof.py
    roof = T([1,2])([roofMeasure[1][0]/.03,roofMeasure[1][1]/.03])(myRoofTerrace(house,PI/5,3))
    house = STRUCT([house,T(3)(6)(roof)])
    return house

#parametri per la costruzione del piano terra
entriesT = ["piano terra/porte.lines","piano terra/serrande.lines","piano terra/finestre.lines"]
floorsT = ["piano terra/pavimentoP.lines","piano terra/pavimentoB.lines","piano terra/pavimentoG.lines"]
wallsT = ["piano terra/perimetro.lines","piano terra/interni.lines"]
elementsOfPlanT = [entriesT, floorsT, wallsT]
#parametri per la costruzione del piano terra
entriesP = ["primo piano/porte.lines",None,"primo piano/finestre.lines"]
floorsP = ["primo piano/pavimentoP.lines","primo piano/pavimentoB.lines",None]
wallsP = ["primo piano/perimetro.lines","primo piano/interni.lines"]
elementsOfPlanP = [entriesP, floorsP, wallsP]
elementsOfHouse = [elementsOfPlanT, elementsOfPlanP]
house = multistoreyHouse(elementsOfHouse)
VIEW(house)
# Out:
# <pyplasm.xgepy.Hpc; proxy of <Swig Object of type 'std::shared_ptr< Hpc > *' at 0x7f016d1495d0> >

# %% [markdown]
# <h2>Screenshot dell'oggetto HPC ottenuto: la casa</h2>

# %% [markdown]
# ![text alt](screen/hpc/f1.png)
# ![text alt](screen/hpc/f2.png)
# ![text alt](screen/hpc/f3.png)
# ![text alt](screen/hpc/f5.png)
# ![text alt](screen/hpc/f6.png)
# ![text alt](screen/hpc/f7.png)
# ![text alt](screen/hpc/f8.png)
# ![text alt](screen/hpc/f9.png)
# ![text alt](screen/hpc/f10.png)
# ![text alt](screen/hpc/f11.png)
# ![text alt](screen/hpc/f12.png)
# ![text alt](screen/hpc/f13.png)
